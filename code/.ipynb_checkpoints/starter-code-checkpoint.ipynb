# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# You are part of the academic staff of a **NEW** public high school in **New York** and have been tasked to assess if standardized tests should be adopted in your school.

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# #### Supplementary Information
#
# At the heart of the controversy, opponents of standardized tests argue that such tests put wealthy students at an advantage. Such students are more likely to get special arrangements during assessments(e.g. due to special needs diagnosis such as ADHD); receive better academic support(e.g. private tuition); and can afford to take the tests multiple times ([*CNBC, 2019*](https://www.cnbc.com/2019/10/03/rich-students-get-better-sat-scores-heres-why.html)). At a higher level, wealthier districts have schools which receive better funding, and can better support their students ([*ALMY Education, 2020*](https://www.almyeducation.com/blog/sat-why-all-the-controversy-part-1)).

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# **To-Do:** *Fill out this cell with the datasets you will use for your analysis. Write a brief description of the contents for each dataset that you choose.*

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# #### Other information
# Range for ACT and SAT results
#
# |Test|Range of Scores|
# |:---|:---:|
# |ACT Composite Score|1 to 36|
# |ACT Sections (Math, Reading, Science)|1 to 36|
# |SAT Total Score|400 to 1600|
# |SAT Secctions|200 to 800|

# %% [markdown]
# Sources:
# ([*ACT Scoring*](https://satsuite.collegeboard.org/media/pdf/understanding-your-sat-score-report.pdf))
# ([*SAT Scoring*](https://satsuite.collegeboard.org/sat/scores/understanding-scores/how-scores-are-calculated))
#
# **Definitions**<br/>
# Test Optional: Submission of ACT or SAT scores during application is optional. Universities will take these results into consideration if included. (This is in contrast to test blind, where universities will not consider ACT or SAT scores even if submitted)

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Create Function to Manually calculate mean:
def isNaN(num):
    return num!= num

def cal_mean(num_list):
    total=0
    length=len(num_list)
    for num in num_list:
        if isNaN(num):
            length -= 1
        else:
            total+=num
    return total/length

# %%
# check code
import numpy as np

lis = np.random.randint(10, size=10)
lis = np.append(lis, [np.nan, 2])

#testing
print(cal_mean(lis))
print(np.nanmean(lis))
#cal_mean(lis)==np.nanmean(lis)
# Out:
# 4.909090909090909
# 4.909090909090909

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Create function to manually calculate mean:

def cal_sd(num_list):
    sum_of_sq=0
    length=len(num_list)
    lis_mean=cal_mean(num_list)
    for num in num_list:
        if isNaN(num):
            length -= 1
        else:
            sum_of_sq += (num - lis_mean)**2
    return (sum_of_sq/length)**0.5

# %%
# check code
lis = np.random.randint(10, size=10)
lis = np.append(lis, [np.nan, 2])

# testing
print(cal_sd(lis))
print(np.nanstd(lis, ddof=0))
#cal_sd(lis)==np.nanstd(lis, ddof=0)
# Out:
# 3.2192602199319587
# 3.2192602199319587

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
# Code:

def percen_to_float(string):
    num = string.replace('%', '')
    num = float(num)/100
    return num

percen_to_float('83.5%')
# Out:
# 0.835

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Imports:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %% [markdown]
# ### Data cleaning for act_2017 dataset

# %%
#act_2017 data cleaning
#1 Load and View data
act_2017 = pd.read_csv('../data/act_2017.csv')
act_2017.head()
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4

# %%
#act_2017 data cleaning
#2 Get data types and missing values
act_2017.info() # 'Composite' variable expected to be numeric, but labelled as string
                # No missing/NA values

#3 Check numeric data summary stats
act_2017.describe() # Science variable appear to have outliers
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     object
# dtypes: float64(4), object(3)
# memory usage: 3.0+ KB
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.040385
# std     2.332132   1.963602   2.048672   3.151113
# min    16.300000  18.000000  18.100000   2.300000
# 25%    19.000000  19.400000  20.475000  19.900000
# 50%    20.550000  20.900000  21.700000  21.150000
# 75%    23.300000  23.100000  24.125000  22.525000
# ...

# %%
#act_2017 data cleaning
#4 Data Cleaning

#4a Attempt to rectify 'Composite'
#act_2017['Composite'].astype(float) # ValueError is thrown when typecasting is attempted

finder=[]
for count, value in enumerate(act_2017['Composite']):
    try:
        float(value)
        finder.append(False)
    except ValueError:
        finder.append(True)
act_2017[finder]


act_2017.loc[51, 'Composite'] = 20.2 # Manually edited the cell as it is likely a typo

act_2017['Composite'] = act_2017['Composite'].astype(float) # Successful typecasting on 'Composite' variable

# %%
#act_2017 data cleaning
#4b Explore Science column
act_2017.sort_values('Science', ascending=True).head() # One cell appears to have an outlier
                                                       # However, since it is within the range of possible values 
                                                       # and not utilised for analysis, no edits are made.
# Out:
#              State Participation  English  Math  Reading  Science  Composite
# 21        Maryland           28%     23.3  23.1     24.2      2.3       23.6
# 29          Nevada          100%     16.3  18.0     18.1     18.2       17.8
# 25     Mississippi          100%     18.2  18.1     18.8     18.8       18.6
# 41  South Carolina          100%     17.5  18.6     19.1     18.9       18.7
# 34  North Carolina          100%     17.8  19.3     19.6     19.3       19.1

# %%
#act_2017 data cleaning
#5 apply percen_to_float function
act_2017['Participation']=act_2017['Participation'].map(percen_to_float)

# %%
#act_2017 data cleaning
#6 edit Column Names
act_2017.columns = act_2017.columns.str.lower()

#7 extract required columns
act_2017 = act_2017[['state', 'participation', 'composite']]

#8 View data after cleaning/transformation
act_2017.info()
act_2017.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   state          52 non-null     object
#  1   participation  52 non-null     float64
#  2   composite      52 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.3+ KB
#        participation  composite
# count      52.000000  52.000000
# mean        0.651538  21.509615
# std         0.318325   2.002083
# min         0.080000  17.800000
# 25%         0.310000  19.800000
# 50%         0.680000  21.400000
# 75%         1.000000  23.600000
# max         1.000000  25.500000

# %% [markdown]
# ### Data cleaning for act_2018 dataset

# %%
#act_2018 data cleaning
#1 Load and View data
act_2018 = pd.read_csv('../data/act_2018.csv')
act_2018.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7

# %%
#act_2018 data cleaning
#2 Get data types and missing values
act_2018.info() # No values stored as NA

#3 Check numeric data summary stats
act_2018.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   Composite      52 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB
#        Composite
# count  52.000000
# mean   21.544231
# std     2.119417
# min    17.700000
# 25%    19.975000
# 50%    21.300000
# 75%    23.725000
# max    25.600000

# %%
#act_2018 data cleaning
#4 Data Cleaning - No observable issues with data
#5 apply percen_to_float function
act_2018['Participation']=act_2018['Participation'].apply(percen_to_float)

# %%
#act_2018 data cleaning
#6 edit Column Names
act_2018.columns = act_2018.columns.str.lower()

#7 extract required columns
act_2018 = act_2018[['state', 'participation', 'composite']]

#8 View data after cleaning/transformation
act_2018.info()
act_2018.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   state          52 non-null     object
#  1   participation  52 non-null     float64
#  2   composite      52 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.3+ KB
#        participation  composite
# count      52.000000  52.000000
# mean        0.606731  21.544231
# std         0.345456   2.119417
# min         0.070000  17.700000
# 25%         0.270000  19.975000
# 50%         0.655000  21.300000
# 75%         1.000000  23.725000
# max         1.000000  25.600000

# %% [markdown]
# ### Data cleaning for act_2019 dataset

# %%
#act_2019 data cleaning
#1 Load and View data
act_2019 = pd.read_csv('../data/act_2019.csv')
act_2019.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       18.9
# 1      Alaska           38%       20.1
# 2     Arizona           73%       19.0
# 3    Arkansas          100%       19.3
# 4  California           23%       22.6

# %%
#act_2019 data cleaning
#2 Get data types and missing values
act_2019.info() # No values stored as NA

#3 Check numeric data summary stats
act_2019.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   Composite      52 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB
#        Composite
# count  52.000000
# mean   21.450000
# std     2.175487
# min    17.900000
# 25%    19.800000
# 50%    20.950000
# 75%    23.650000
# max    25.500000

# %%
#act_2019 data cleaning
#4 Data Cleaning - No observable issues with data
#5 apply percen_to_float function
act_2019['Participation']=act_2019['Participation'].apply(percen_to_float)

# %%
#act_2019 data cleaning
#6 edit Column Names
act_2019.columns = act_2019.columns.str.lower()

#7 extract required columns

#8 View data after cleaning/transformation
act_2019.info()
act_2019.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   state          52 non-null     object
#  1   participation  52 non-null     float64
#  2   composite      52 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.3+ KB
#        participation  composite
# count      52.000000  52.000000
# mean        0.585385  21.450000
# std         0.341883   2.175487
# min         0.060000  17.900000
# 25%         0.247500  19.800000
# 50%         0.530000  20.950000
# 75%         1.000000  23.650000
# max         1.000000  25.500000

# %% [markdown]
# ### Data cleaning for sat_2017 dataset

# %%
#sat_2017 data cleaning
#1 Load and View data
sat_2017 = pd.read_csv('../data/sat_2017.csv')
sat_2017.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055

# %%
#sat_2017 data cleaning
#2 Get data types and missing values
sat_2017.info() # No values stored as NA
    
#3 Check numeric data summary stats
sat_2017.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  547.627451  1126.098039
# std                             45.666901   84.909119    92.494812
# min                            482.000000   52.000000   950.000000
# ...

# %%
#sat_2017 data cleaning
#4 Data Cleaning
# Attempt to rectify 'Math'
sat_2017.sort_values('Math', ascending=True).head() # Row Index 20, Math appears to be a typo 
                                                    # as values are beyond the prescribed range
                                                    # However, no edits are made as we are not using this variable
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 20              Maryland           69%                                 536
# 8   District of Columbia          100%                                 482
# 7               Delaware          100%                                 503
# 12                 Idaho           93%                                 513
# 22              Michigan          100%                                 509
#
#     Math  Total
# 20    52   1060
# 8    468    950
# 7    492    996
# 12   493   1005
# 22   495   1005

# %%
#sat_2017 data cleaning
#5 apply percen_to_float function
sat_2017['Participation']=sat_2017['Participation'].apply(percen_to_float)

# %%
#sat_2017 data cleaning
#6 edit Column Names
sat_2017.columns = sat_2017.columns.str.lower()

#7 extract required columns
sat_2017 = sat_2017[['state', 'participation', 'total']]

#8 View data after cleaning
sat_2017.info()
sat_2017.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   state          51 non-null     object
#  1   participation  51 non-null     float64
#  2   total          51 non-null     int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.3+ KB
#        participation        total
# count      51.000000    51.000000
# mean        0.398039  1126.098039
# std         0.352766    92.494812
# min         0.020000   950.000000
# 25%         0.040000  1055.500000
# 50%         0.380000  1107.000000
# 75%         0.660000  1212.000000
# max         1.000000  1295.000000

# %% [markdown]
# ### Data cleaning for sat_2018 dataset

# %%
#sat_2018 data cleaning
#1 Load and View data
sat_2018 = pd.read_csv('../data/sat_2018.csv')
sat_2018.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076

# %%
#sat_2018 data cleaning
#2 Get data types and missing values
sat_2018.info() # 'Composite' variable expected to be numeric, but shows as string
                # No values stored as NA
    
#3 Check numeric data summary stats
sat_2018.describe() # Math column appear to have extreme outliers
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           563.686275  556.235294  1120.019608
# std                             47.502627   47.772623    94.155083
# min                            480.000000  480.000000   977.000000
# ...

# %%
#sat_2018 data cleaning
#4 Data Cleaning - No observable issues with data
#5 apply percen_to_float function
sat_2018['Participation']=sat_2018['Participation'].map(percen_to_float)

# %%
#sat_2018 dataset
#6 Edit Column Names
sat_2018.columns = sat_2018.columns.str.lower()

#7 extract required columns
sat_2018 = sat_2018[['state', 'participation', 'total']]

#8 View data after cleaning
sat_2018.info()
sat_2018.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   state          51 non-null     object
#  1   participation  51 non-null     float64
#  2   total          51 non-null     int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.3+ KB
#        participation        total
# count      51.000000    51.000000
# mean        0.457451  1120.019608
# std         0.373143    94.155083
# min         0.020000   977.000000
# 25%         0.045000  1057.500000
# 50%         0.520000  1098.000000
# 75%         0.775000  1204.000000
# max         1.000000  1298.000000

# %% [markdown]
# ### Data cleaning for sat_2019 dataset

# %%
#sat_2019 data cleaning
#1 Load and View data
sat_2019 = pd.read_csv('../data/sat_2019.csv')
sat_2019.head()
# Out:
#         State Participation Rate  EBRW  Math  Total
# 0     Alabama                 7%   583   560   1143
# 1      Alaska                41%   556   541   1097
# 2     Arizona                31%   569   565   1134
# 3    Arkansas                 6%   582   559   1141
# 4  California                63%   534   531   1065

# %%
#sat_2019 dataset
#2 Get data types and missing values
sat_2019.info() # No values stored as NA
    
#3 Check numeric data summary stats
sat_2019.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               53 non-null     object
#  1   Participation Rate  53 non-null     object
#  2   EBRW                53 non-null     int64
#  3   Math                53 non-null     int64
#  4   Total               53 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.2+ KB
#              EBRW        Math        Total
# count   53.000000   53.000000    53.000000
# mean   558.000000  548.471698  1106.528302
# std     47.554422   53.785044   100.994784
# min    483.000000  445.000000   935.000000
# 25%    518.000000  506.000000  1024.000000
# 50%    550.000000  545.000000  1097.000000
# 75%    610.000000  596.000000  1200.000000
# max    636.000000  648.000000  1284.000000

# %%
#sat_2019 data cleaning
#4 Data Cleaning

#5 apply percen_to_float function
#sat_2019['Participation Rate']=sat_2019['Participation Rate'].apply(percen_to_float) # ValueError

finder=[]
for count, value in enumerate(sat_2019['Participation Rate']):
    try:
        percen_to_float(value)
        finder.append(False)
    except ValueError:
        finder.append(True)

sat_2019[finder] # 2 problematic values

sat_2019.drop(index=sat_2019.index[[39, 47]], # remove Puerto Rico and Virgin Islands as they are not US states
        axis=0,
        inplace=True)

sat_2019.loc[sat_2019['State'] == 'Virgin Islands', 'Participation Rate'] = np.nan              
                                        # Change Virgin Islands to NaN value
    
#5 apply percen_to_float function
sat_2019['Participation Rate']=sat_2019['Participation Rate'].map(percen_to_float, na_action='ignore')

# %%
#sat_2019 data cleaning
#6 Edit Column Names
sat_2019.columns = sat_2019.columns.str.lower()

#7 extract required columns
sat_2019 = sat_2019[['state', 'participation rate', 'total']]
sat_2019 = sat_2019.rename(columns={'participation rate': 'participation'})

#8 View data after cleaning
sat_2019.info()
sat_2019.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 52
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   state          51 non-null     object
#  1   participation  51 non-null     float64
#  2   total          51 non-null     int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.6+ KB
#        participation        total
# count      51.000000    51.000000
# mean        0.490588  1113.078431
# std         0.387476    97.197910
# min         0.020000   943.000000
# 25%         0.055000  1038.000000
# 50%         0.540000  1097.000000
# 75%         0.820000  1210.000000
# max         1.000000  1284.000000

# %% [markdown]
# ### Data cleaning for sat_act_by_college dataset

# %%
#sat_act_by_college data cleaning
#1 Load and View data
sat_act_by_college = pd.read_csv('../data/sat_act_by_college.csv')
sat_act_by_college.head()
# Out:
#                  School Test Optional? Applies to Class Year(s)  \
# 0   Stanford University            Yes                     2021
# 1       Harvard College            Yes                     2021
# 2  Princeton University            Yes                     2021
# 3   Columbia University            Yes                     2021
# 4       Yale University            Yes                     2021
#
#                                       Policy Details  Number of Applicants  \
# 0  Stanford has adopted a one-year test optional ...                 47452
# 1  Harvard has adopted a one-year test optional p...                 42749
# 2  Princeton has adopted a one-year test optional...                 35370
# 3  Columbia has adopted a one-year test optional ...                 40203
# 4  Yale has adopted a one-year test optional poli...                 36844
#
#   Accept Rate SAT Total 25th-75th Percentile ACT Total 25th-75th Percentile
# ...

# %%
#sat_act_by_college dataset
#2 Get data types and missing values
sat_act_by_college.info() # required variables have no NAs
    
#3 Check numeric data summary stats
sat_act_by_college.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 416 entries, 0 to 415
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   School                          416 non-null    object
#  1   Test Optional?                  416 non-null    object
#  2   Applies to Class Year(s)        390 non-null    object
#  3   Policy Details                  416 non-null    object
#  4   Number of Applicants            416 non-null    int64
#  5   Accept Rate                     416 non-null    object
#  6   SAT Total 25th-75th Percentile  416 non-null    object
#  7   ACT Total 25th-75th Percentile  416 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 26.1+ KB
#        Number of Applicants
# count            416.000000
# mean           17481.759615
# std            17447.621897
# min              211.000000
# 25%             5313.000000
# 50%            11622.000000
# ...

# %%
#sat_act_by_college dataset
# Deeper exploration of data
sat_act_by_college['Test Optional?'].value_counts()

#recode variables

sat_act_by_college['test_optional']\
=sat_act_by_college['Test Optional?'].map(lambda x: 'No' if x in ['No', 'Yes*'] else ('TB' if x == 'Yes (TB)' else 'Yes'))

#sat_act_by_college['Applies to Class Year(s)'].value_counts()
#sat_act_by_college.loc[sat_act_by_college['Test Optional?'] == 'Yes', 'Policy Details']
#sat_act_by_college.loc[sat_act_by_college['Test Optional?'] == 'No', 'Policy Details']
#sat_act_by_college.loc[sat_act_by_college['Test Optional?'] == 'Yes (TB)', 'Policy Details']
#sat_act_by_college.loc[sat_act_by_college['Test Optional?'] == 'Yes*', 'Policy Details']
#sat_act_by_college.loc[sat_act_by_college['Test Optional?'] == 'Yes (TF)', 'Policy Details']

# %%
#sat_act_by_college dataset
#4 Edit Column Names
sat_act_by_college.columns = sat_act_by_college.columns.str.lower()

#5 extract required columns
sat_act_by_college = sat_act_by_college[['school', 'test_optional']]

#6 View data after cleaning
sat_act_by_college.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 416 entries, 0 to 415
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   school         416 non-null    object
#  1   test_optional  416 non-null    object
# dtypes: object(2)
# memory usage: 6.6+ KB

# %% [markdown]
# ## Merge Datasets

# %%
# Merge ACT_SAT datasets

act = pd.merge(left = act_2017,
               right = act_2018,
               on = 'state',
               how = 'outer',
               suffixes=('_2017', '_2018'))

#add year suffix to act_2019 columns before merging
act_2019 = act_2019.rename(columns={'participation': 'participation_2019',
                                   'composite':'composite_2019',
                                   'year':'year_2019'})

act = pd.merge(left = act,
               right = act_2019,
               on = 'state',
                how = 'outer')

#View data
act.head()
# Out:
#       state  participation_2017  composite_2017  participation_2018  \
# 0  National                0.60            21.0                 NaN
# 1   Alabama                1.00            19.2                1.00
# 2    Alaska                0.65            19.8                0.33
# 3   Arizona                0.62            19.7                0.66
# 4  Arkansas                1.00            19.4                1.00
#
#    composite_2018  participation_2019  composite_2019
# 0             NaN                0.52            20.7
# 1            19.1                1.00            18.9
# 2            20.8                0.38            20.1
# 3            19.2                0.73            19.0
# 4            19.4                1.00            19.3

# %%
# Merge ACT datasets
#2 Get data types and missing values
act.info() # Several NA values

#3 Check numeric data summary stats
act.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 54 entries, 0 to 53
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   state               54 non-null     object
#  1   participation_2017  53 non-null     float64
#  2   composite_2017      53 non-null     float64
#  3   participation_2018  52 non-null     float64
#  4   composite_2018      52 non-null     float64
#  5   participation_2019  53 non-null     float64
#  6   composite_2019      53 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 3.4+ KB
#        participation_2017  composite_2017  participation_2018  composite_2018  \
# count           53.000000       53.000000           52.000000       52.000000
# mean             0.640755       21.562264            0.606731       21.544231
# std              0.324878        2.019446            0.345456        2.119417
# ...

# %%
# View Nan rows
act.loc[act['participation_2017'].isnull(), ] # 2018 has different capitalisations of state name
                                              # compared to 2017 and 2019 dataset
# Out:
#                    state  participation_2017  composite_2017  \
# 53  District of columbia                 NaN             NaN
#
#     participation_2018  composite_2018  participation_2019  composite_2019
# 53                0.32            23.6                 NaN             NaN

# %%
# View Nan rows
act[act['participation_2018'].isnull()] # 2018 has no national level participation rates
                                        # Since sat data has no national level info as well,
                                        # will remove national level data
# Out:
#                   state  participation_2017  composite_2017  \
# 0              National                0.60            21.0
# 9  District of Columbia                0.32            24.2
#
#    participation_2018  composite_2018  participation_2019  composite_2019
# 0                 NaN             NaN                0.52            20.7
# 9                 NaN             NaN                0.32            23.5

# %%
# Merge ACT datasets
#4 Data cleaning

#combine rows with same state names
DC_2018 = act.loc[act['state'] == 'District of columbia', ['participation_2018', 'composite_2018']]
act.loc[act['state'] == 'District of Columbia', ['participation_2018']] = DC_2018['participation_2018'][53]
act.loc[act['state'] == 'District of Columbia', ['composite_2018']] = DC_2018['composite_2018'][53]

#drop extra row with diff state name
act.drop(index=act.index[[0, 53]],
        axis=0,        
        inplace=True)

act.loc[act['state'] == 'District of Columbia']
# Out:
#                   state  participation_2017  composite_2017  \
# 9  District of Columbia                0.32            24.2
#
#    participation_2018  composite_2018  participation_2019  composite_2019
# 9                0.32            23.6                0.32            23.5

# %%
# Check for duplicates
act[act.duplicated(keep=False)] # Duplicate row, state of Maine

act.drop(index=act.index[20], # Drop duplicate
        axis=0,        
        inplace=True)

# %%
act[act.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [state, participation_2017, composite_2017, participation_2018, composite_2018, participation_2019, composite_2019]
# Index: []

# %%
#5 View data after cleaning
act.info() #expected null values in 2018 due to no national rates
act.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 1 to 52
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   state               51 non-null     object
#  1   participation_2017  51 non-null     float64
#  2   composite_2017      51 non-null     float64
#  3   participation_2018  51 non-null     float64
#  4   composite_2018      51 non-null     float64
#  5   participation_2019  51 non-null     float64
#  6   composite_2019      51 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 3.2+ KB
#        participation_2017  composite_2017  participation_2018  composite_2018  \
# count           51.000000       51.000000           51.000000       51.000000
# mean             0.652549       21.519608            0.617255       21.496078
# std              0.321408        2.020695            0.340371        2.111583
# ...

# %%
# Merge SAT datasets

sat = pd.merge(left = sat_2017,
               right = sat_2018,
               on = 'state',
               how = 'outer',
               suffixes=('_2017', '_2018'))

#add year suffix to act_2019 columns before merging
sat_2019 = sat_2019.rename(columns={'participation': 'participation_2019',
                                   'total':'total_2019',
                                   'total':'total_2019'})

sat = pd.merge(left = sat,
               right = sat_2019,
               on = 'state',
                how = 'outer')

#View data
sat.head()
# Out:
#         state  participation_2017  total_2017  participation_2018  total_2018  \
# 0     Alabama                0.05        1165                0.06        1166
# 1      Alaska                0.38        1080                0.43        1106
# 2     Arizona                0.30        1116                0.29        1149
# 3    Arkansas                0.03        1208                0.05        1169
# 4  California                0.53        1055                0.60        1076
#
#    participation_2019  total_2019
# 0                0.07        1143
# 1                0.41        1097
# 2                0.31        1134
# 3                0.06        1141
# 4                0.63        1065

# %%
# Merge ACT datasets
#2 Get data types and missing values
sat[sat.duplicated(keep=False)] # check for duplicates
sat.info() # Several NA values

#3 Check numeric data summary stats
sat.describe()

#no obeservable issues
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   state               51 non-null     object
#  1   participation_2017  51 non-null     float64
#  2   total_2017          51 non-null     int64
#  3   participation_2018  51 non-null     float64
#  4   total_2018          51 non-null     int64
#  5   participation_2019  51 non-null     float64
#  6   total_2019          51 non-null     int64
# dtypes: float64(3), int64(3), object(1)
# memory usage: 3.2+ KB
#        participation_2017   total_2017  participation_2018   total_2018  \
# count           51.000000    51.000000           51.000000    51.000000
# mean             0.398039  1126.098039            0.457451  1120.019608
# std              0.352766    92.494812            0.373143    94.155083
# min              0.020000   950.000000            0.020000   977.000000
# ...

# %%
# Merge ACT and SAT datasets

act_sat = pd.merge(left = act,
               right = sat,
               on = 'state',
               how = 'outer',
               suffixes=('_act', '_sat'))

# %%
# View data
# view data and descriptions
act_sat.info()
act_sat.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   51 non-null     object
#  1   participation_2017_act  51 non-null     float64
#  2   composite_2017          51 non-null     float64
#  3   participation_2018_act  51 non-null     float64
#  4   composite_2018          51 non-null     float64
#  5   participation_2019_act  51 non-null     float64
#  6   composite_2019          51 non-null     float64
#  7   participation_2017_sat  51 non-null     float64
#  8   total_2017              51 non-null     int64
#  9   participation_2018_sat  51 non-null     float64
#  10  total_2018              51 non-null     int64
#  11  participation_2019_sat  51 non-null     float64
#  12  total_2019              51 non-null     int64
# dtypes: float64(9), int64(3), object(1)
# memory usage: 5.6+ KB
# ...

# %%
act_sat.to_csv('../data/ACT_SAT_combined.csv', index = False)
sat_act_by_college.to_csv('../data/college_entry.csv', index = False)

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# #### Data Dictionary
#
# |DataSet|Feature|Type|Description|
# |:---|:---|:---|:---|
# |act_sat|participation|float|Participation rate of the US state for ACT or SAT tests in that year.|
# |act_sat|state|string|US State|
# |act_sat|composite|float|Average ACT test scores of the respective US state in that year.|
# |act_sat|total|integer|Average SAT test scores of the respective US state in that year.|
# |admission|school|string|Name of school|
# |admission|test_optional|string|Yes: Test Optional and Test flexible schools <br/> No: Schools which require SAT/ACT, and schools which <br/> have specific conditions if applicants do not submit SAT/ACT <br/> TB: Test Blind, rests will not be considered even if submitted
#
# Note: For the act_sat dataset, each feature is suffixed with the year that the data represents

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
#Summary statistics for act_sat
act_sat.info()
act_sat.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   51 non-null     object
#  1   participation_2017_act  51 non-null     float64
#  2   composite_2017          51 non-null     float64
#  3   participation_2018_act  51 non-null     float64
#  4   composite_2018          51 non-null     float64
#  5   participation_2019_act  51 non-null     float64
#  6   composite_2019          51 non-null     float64
#  7   participation_2017_sat  51 non-null     float64
#  8   total_2017              51 non-null     int64
#  9   participation_2018_sat  51 non-null     float64
#  10  total_2018              51 non-null     int64
#  11  participation_2019_sat  51 non-null     float64
#  12  total_2019              51 non-null     int64
# dtypes: float64(9), int64(3), object(1)
# memory usage: 5.6+ KB
# ...

# %%
#Summary statistics for act_sat
act_sat.describe()
# Out:
#        participation_2017_act  composite_2017  participation_2018_act  \
# count               51.000000       51.000000               51.000000
# mean                 0.652549       21.519608                0.617255
# std                  0.321408        2.020695                0.340371
# min                  0.080000       17.800000                0.070000
# 25%                  0.310000       19.800000                0.285000
# 50%                  0.690000       21.400000                0.660000
# 75%                  1.000000       23.600000                1.000000
# max                  1.000000       25.500000                1.000000
#
#        composite_2018  participation_2019_act  composite_2019  \
# count       51.000000               51.000000       51.000000
# mean        21.496078                0.586667       21.464706
# std          2.111583                0.345159        2.194523
# min         17.700000                0.060000       17.900000
# ...

# %%
#Summary statistics for sat_act_by_college
sat_act_by_college.info()
sat_act_by_college['test_optional'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 416 entries, 0 to 415
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   school         416 non-null    object
#  1   test_optional  416 non-null    object
# dtypes: object(2)
# memory usage: 6.6+ KB
# Yes    349
# No      42
# TB      25
# Name: test_optional, dtype: int64

# %% [markdown]
# ### Standard Deviation Dictionary

# %%
#Code:
#square_dict = {num: num*num for num in range(1, 11)}

act_sat_sd_dict = {(col_name+'_sd'):round(cal_sd(col_data), 2) 
           for col_name, col_data in act_sat.iteritems()
           if (col_data.dtype == 'int64') | (col_data.dtype == float)}
act_sat_sd_dict
# Out:
# {'participation_2017_act_sd': 0.32,
#  'composite_2017_sd': 2.0,
#  'participation_2018_act_sd': 0.34,
#  'composite_2018_sd': 2.09,
#  'participation_2019_act_sd': 0.34,
#  'composite_2019_sd': 2.17,
#  'participation_2017_sat_sd': 0.35,
#  'total_2017_sd': 91.58,
#  'participation_2018_sat_sd': 0.37,
#  'total_2018_sd': 93.23,
#  'participation_2019_sat_sd': 0.38,
#  'total_2019_sd': 96.24}

# %% [markdown]
# ### Investigate trends in the data

# %%
# Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
act_sat.sort_values('participation_2017_act', ascending = True).head()
act_sat.sort_values('participation_2017_act', ascending = False).head(20)

act_sat.sort_values('participation_2017_sat', ascending = True).head()
act_sat.sort_values('participation_2017_sat', ascending = False).head(20)
# Out:
#                    state  participation_2017_act  composite_2017  \
# 8   District of Columbia                    0.32            24.2
# 22              Michigan                    0.29            24.1
# 6            Connecticut                    0.31            25.2
# 7               Delaware                    0.18            24.1
# 29         New Hampshire                    0.18            25.5
# 19                 Maine                    0.08            24.3
# 12                 Idaho                    0.38            22.3
# 9                Florida                    0.73            19.8
# 21         Massachusetts                    0.29            25.4
# 39          Rhode Island                    0.21            24.0
# 30            New Jersey                    0.34            23.9
# 20              Maryland                    0.28            23.6
# 32              New York                    0.31            24.2
# ...

# %% [markdown]
# ACT participation in 2017:<br/>
# In 2017, state of Maine had the lowest participation for ACT at 0.08.
# In 2017, the following states fully participated in the ACT Alabama, Arkansas, Colorado, Kentucky, Louisiana, Minnesota, Mississippi, Missouri, Montana, Nevada, North Carolina, Oklahoma, South Carolina, Tennessee, Utah, Wisconsin, Wyoming.
#
# SAT participation in 2017:<br/>
# In 2017, states of North Dakota, Mississippi and Iowa had the lowest participation for SAT at 0.02.
# In 2017, the following states fully participated in the SAT District of Columbia (Washington DC), Michigan, Connecticut and Delaware.

# %%
# Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
act_sat.loc[act_sat['composite_2017'] == act_sat['composite_2017'].min(), ['state', 'composite_2017']]
act_sat.loc[act_sat['composite_2017'] == act_sat['composite_2017'].max(), ['state', 'composite_2017']]

act_sat.loc[act_sat['total_2017'] == act_sat['total_2017'].min(), ['state', 'total_2017']]
act_sat.loc[act_sat['total_2017'] == act_sat['total_2017'].max(), ['state', 'total_2017']]

#act.sort_values('participation_2017', ascending = True).head()
#act.sort_values('participation_2017', ascending = False).head(20)
# Out:
#         state  total_2017
# 23  Minnesota        1295

# %% [markdown]
# In 2017, Nevada had the lowest mean score for ACT at 17.8.
# In 2017, New Hampshire had the highest mean score for ACT at 25.5.
#
# In 2017, District of Columbia had the lowest mean score for SAT at 950.
# In 2017, Minnesota had the highest mean score for SAT at 1295.

# %%
# Do any states with 100% participation on a given test have a rate change year-to-year?

act_sat.loc[act_sat['participation_2017_act']==1].sort_values('participation_2018_act', ascending=True)
act_sat.loc[act_sat['participation_2017_sat']==1].sort_values('participation_2018_sat', ascending=True)
# Out:
#                    state  participation_2017_act  composite_2017  \
# 8   District of Columbia                    0.32            24.2
# 6            Connecticut                    0.31            25.2
# 7               Delaware                    0.18            24.1
# 22              Michigan                    0.29            24.1
#
#     participation_2018_act  composite_2018  participation_2019_act  \
# 8                     0.32            23.6                    0.32
# 6                     0.26            25.6                    0.22
# 7                     0.17            23.8                    0.13
# 22                    0.22            24.2                    0.19
#
#     composite_2019  participation_2017_sat  total_2017  \
# 8             23.5                     1.0         950
# 6             25.5                     1.0        1041
# 7             24.1                     1.0         996
# 22            24.4                     1.0        1005
#
# ...

# %% [markdown]
# States with 100% participation on a given test largelyy maintain their participation rates year-to-year.
# In 2017, 17 states had a 100% participation rate for ACT. States with 100% participation rates for ACT dropped slightly to 15 and 13 in 2018 and 2019 respectively. Likewise for SAT, 4 states had a 100% participation rate in 2017. States with 100% participation rates for SAT dropped marginally to 3 in 2018 and 2019.
#
# Generally, those whose rates did drop still maintained high participation of at least 78% thereafter. The only exception is Colorado, whose ACT participation dropped from 100% in 2017 to 30% in 2018.

# %%
# Do any states show have >50% participation on both tests each year?
act_sat.loc[(act_sat['participation_2017_act']>0.5) & (act_sat['participation_2017_sat']>0.5),
           ['state','participation_2017_act', 'participation_2017_sat']]

act_sat.loc[(act_sat['participation_2018_act']>0.5) & (act_sat['participation_2018_sat']>0.5),
           ['state','participation_2018_act', 'participation_2018_sat']]

act_sat.loc[(act_sat['participation_2019_act']>0.5) & (act_sat['participation_2019_sat']>0.5),
           ['state','participation_2019_act', 'participation_2019_sat']]
# Out:
#              state  participation_2019_act  participation_2019_sat
# 9          Florida                    0.54                    1.00
# 11          Hawaii                    0.80                    0.54
# 33  North Carolina                    1.00                    0.51
# 40  South Carolina                    0.78                    0.68

# %% [markdown]
# Therea following states have the more than 50% participation rates on both tests in the same year:
# 1. 2017, Florida, Georgia and Hawaii
# 2. 2018, Florida, Georgia, Hawaii, North Carolina and South Carolina
# 3. 2019, Florida, Hawaii, North Carolina and South Carolina

# %%
act_sat.sort_values('total_2019', ascending = False).head()
# Out:
#            state  participation_2017_act  composite_2017  \
# 23     Minnesota                    1.00            21.5
# 49     Wisconsin                    1.00            20.5
# 41  South Dakota                    0.80            21.8
# 34  North Dakota                    0.98            20.3
# 27      Nebraska                    0.84            21.4
#
#     participation_2018_act  composite_2018  participation_2019_act  \
# 23                    0.99            21.3                    0.95
# 49                    1.00            20.5                    1.00
# 41                    0.77            21.9                    0.75
# 34                    0.98            20.3                    0.96
# 27                    1.00            20.1                    1.00
#
#     composite_2019  participation_2017_sat  total_2017  \
# 23            21.4                    0.03        1295
# 49            20.3                    0.03        1291
# ...

# %%
# Can I afford not to take standardised tests?
sat_act_by_college['test_optional'].value_counts(normalize=True)
# Out:
# Yes    0.838942
# No     0.100962
# TB     0.060096
# Name: test_optional, dtype: float64

# %% [markdown]
# At least for the academic year of 2021, students will be able to apply for about 90% of universities without taking standardised tests.

# %%
# How does New York perform in standardised tests as compared to other states in 2019?
ny_act_2019 = act_sat.loc[act_sat['state'] == 'New York', 'composite_2019'][32]
ny_sat_2019 = act_sat.loc[act_sat['state'] == 'New York', 'total_2019'][32]
(act_sat.loc[:, 'composite_2019']<ny_act_2019).mean()
(act_sat.loc[:, 'total_2019']<ny_sat_2019).mean()

ny_act_2018 = act_sat.loc[act_sat['state'] == 'New York', 'composite_2018'][32]
(act_sat.loc[:, 'composite_2018']<ny_act_2018).mean()

ny_act_2019 = act_sat.loc[act_sat['state'] == 'New York', 'composite_2019'][32]
(act_sat.loc[:, 'composite_2019']<ny_act_2019).mean()
# Out:
# 0.9019607843137255

# %% [markdown]
# From 2017 to 2019, New York performed better than at least 90% of the US states in ACT.

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
# Establish size of figure.
plt.figure(figsize = (16,9))

# Get correlation of variables.
corr = act_sat.corr()

# Set up mask to be "True" in the upper triangle.
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
plt.title('Heatmap of participation rates and results of ACT and SAT tests in US states from 2017 to 2019')

# Plot our correlation heatmap, while masking the upper triangle to be white.
with sns.axes_style("white"):
    sns.heatmap(corr, mask = mask, square = True, annot = True, vmin = -1, vmax = 1, linewidths = .5)

# %% [markdown]
# Participation rates for a test in one year is positively correlated to participation rates of the same test in subsequent years. For example, if a state has high participation rate for ACT in 2017, that state will likely have high participation rate for ACT in 2018.
#
# Participation rates in one test is negatively correlated with participation rates in the other test. This means that States with higher participation rates in ACT will have lower participation rates in SATs. This relationship is consistent across years.
#
# Test scores for a test in one year is positively correlated to test scores of the same test in subsequent years. If a state has high scores for ACT in 2017, that state will likely have high high scores for ACT in 2018.
#
# Test scores in one test is negatively correlated with test scores in the other test. This means that States with higher scores in ACT will have lower scores in SATs. This relationship is consistent across years.
#
# However, the correlation for participation rates (r > |0.7|) are generally stronger than correlations for test scores (|0.3| r < |0.5|)

# %% [markdown]
# ### Histograms for ACT participation rates from 2017 to 2019

# %%
s = np.arange(0, 1.1, 0.1)
s = [round(i, 2) for i in s]

# %%
# Code
#Have a title
#Have axis labels
#Have appropriate tick labels
#Text is legible in a plot
#Plots demonstrate meaningful and valid relationships
#Have an interpretation to aid understanding
plt.figure(figsize = (9,9))
ax1 = plt.subplot(3, 1, 1)
ax1.hist(act_sat['participation_2017_act'], bins=10)
ax1.set_title("2017")

ax2 = plt.subplot(3, 1, 2, sharex = ax1)
ax2.hist(act_sat['participation_2018_act'])
ax2.set_title("2018")
plt.ylabel("Frequency", fontsize=12)

ax3 = plt.subplot(3, 1, 3, sharex = ax1)
ax3.hist(act_sat['participation_2019_act'])
ax3.set_title("2019")

plt.xlim([0, 1])
plt.xticks(s, s)
plt.xlabel("Participation rates for ACT", fontsize=12)
plt.suptitle('Participation rates for ACT in US states from 2017 to 2019', fontsize=16)
plt.subplots_adjust(hspace = 0.4)   # the amount of height reserved for white space between subplots)

# %% [markdown]
# Participation rates for ACT across the years are generally quite spread out, and have a mode at 100%. There are also few states that have participation rates around 50%.

# %% [markdown]
# ### Histograms for SAT participation rates from 2017 to 2019

# %%
# Code
#Have a title
#Have axis labels
#Have appropriate tick labels
#Text is legible in a plot
#Plots demonstrate meaningful and valid relationships
#Have an interpretation to aid understanding
plt.figure(figsize = (9,9))
ax1 = plt.subplot(3, 1, 1)
ax1.hist(act_sat['participation_2017_sat'], bins=10)
ax1.set_title("2017")
plt.ylim([0, 20])

ax2 = plt.subplot(3, 1, 2, sharex = ax1)
ax2.hist(act_sat['participation_2018_sat'])
ax2.set_title("2018")
plt.ylim([0, 20])
plt.ylabel("Frequency", fontsize=12)

ax3 = plt.subplot(3, 1, 3, sharex = ax1)
ax3.hist(act_sat['participation_2019_sat'])
ax3.set_title("2019")
plt.ylim([0, 20])

plt.xlim([0, 1])
plt.xticks(s, s)
plt.xlabel("Participation rates for SAT", fontsize=12)
plt.suptitle('Participation rates for SAT in US states from 2017 to 2019', fontsize=16)
plt.subplots_adjust(hspace = 0.4)   # the amount of height reserved for white space between subplots)

# %% [markdown]
# Participation rates for SAT across the years are concentrated at the 0% and 100%. There are also few states that have participation rates around 50%

# %% [markdown]
# ### Histograms for ACT composite scores from 2017 to 2019

# %%
# Code
#Have a title
#Have axis labels
#Have appropriate tick labels
#Text is legible in a plot
#Plots demonstrate meaningful and valid relationships
#Have an interpretation to aid understanding
plt.figure(figsize = (9,9))
ax1 = plt.subplot(3, 1, 1)
ax1.hist(act_sat['composite_2017'], bins=10)
ax1.set_title("2017")
plt.ylim([0, 10])

ax2 = plt.subplot(3, 1, 2, sharex = ax1)
ax2.hist(act_sat['composite_2018'])
ax2.set_title("2018")
plt.ylim([0, 10])
plt.ylabel("Frequency", fontsize=12)

ax3 = plt.subplot(3, 1, 3, sharex = ax1)
ax3.hist(act_sat['composite_2019'])
ax3.set_title("2019")
plt.ylim([0, 10])

plt.xlim([0, 36])
plt.xticks(list(range(0, 37, 2)), list(range(0, 37, 2)))
plt.xlabel("ACT Composite Scores", fontsize=12)
plt.suptitle('ACT composite scores in US states from 2017 to 2019', fontsize=16)
plt.subplots_adjust(hspace = 0.4)   # the amount of height reserved for white space between subplots)

# %% [markdown]
# While the range of ACT scores is from 0 to 36, most scores are between 18 and 26. The scores not follow a normal distribution, with more scores hovering around 18 and 26.

# %% [markdown]
# ### Histograms for SAT total scores from 2017 to 2019

# %%
# Code
#Have a title
#Have axis labels
#Have appropriate tick labels
#Text is legible in a plot
#Plots demonstrate meaningful and valid relationships
#Have an interpretation to aid understanding
plt.figure(figsize = (9,9))
ax1 = plt.subplot(3, 1, 1)
ax1.hist(act_sat['total_2017'], bins=10)
ax1.set_title("2017")
plt.ylim([0, 15])

ax2 = plt.subplot(3, 1, 2, sharex = ax1)
ax2.hist(act_sat['total_2018'])
ax2.set_title("2018")
plt.ylim([0, 15])
plt.ylabel("Frequency", fontsize=12)

ax3 = plt.subplot(3, 1, 3, sharex = ax1)
ax3.hist(act_sat['total_2019'])
ax3.set_title("2019")
plt.ylim([0, 15])

plt.xlim([400, 1600])
plt.xticks(list(range(400, 1600, 100)), list(range(400, 1600, 100)))

plt.xlabel("SAT Total Scores", fontsize=12)
plt.suptitle('SAT total scores in US states from 2017 to 2019', fontsize=16)
plt.subplots_adjust(hspace = 0.5)   # the amount of height reserved for white space between subplots)

# %% [markdown]
# While the range of ACT scores is from 400 to 1600, most scores are between 950 and 1300. The scores also do not follow a normal distribution, with more scores hovering around 1050 and 1250.

# %% [markdown]
# ### Boxplots for ACT participation rates from 2017 to 2019

# %%
ax1 = plt.subplot(1, 3, 1)
ax1.boxplot(act_sat['participation_2017_act'], patch_artist=True, boxprops=dict(facecolor='lightgrey'))
ax1.set_title("2017")

ax2 = plt.subplot(1, 3, 2, sharex = ax1)
ax2.boxplot(act_sat['participation_2018_act'], patch_artist=True, boxprops=dict(facecolor='lightgrey'))
ax2.set_title("2018")

ax3 = plt.subplot(1, 3, 3, sharex = ax1)
ax3.boxplot(act_sat['participation_2019_act'], patch_artist=True, boxprops=dict(facecolor='lightgrey'))
ax3.set_title("2019")

plt.suptitle('Participation rates for ACT in US states from 2017 to 2019', fontsize=16)
plt.subplots_adjust(top=0.82)
plt.subplots_adjust(wspace = 0.5)

# %% [markdown]
# The box plots for ACT participation rates are similar across the years. They range greatly, with the 25th and 75th percentile at about 0.3 and 1.0 respectively. The median participation rate is about 60%.

# %% [markdown]
# ### Boxplots for SAT participation rates from 2017 to 2019

# %%
ax1 = plt.subplot(1, 3, 1)
ax1.boxplot(act_sat['participation_2017_sat'], patch_artist=True, boxprops=dict(facecolor='lightgrey'))
ax1.set_title("2017")

ax2 = plt.subplot(1, 3, 2, sharex = ax1)
ax2.boxplot(act_sat['participation_2018_sat'], patch_artist=True, boxprops=dict(facecolor='lightgrey'))
ax2.set_title("2018")

ax3 = plt.subplot(1, 3, 3, sharex = ax1)
ax3.boxplot(act_sat['participation_2019_sat'], patch_artist=True, boxprops=dict(facecolor='lightgrey'))
ax3.set_title("2019")

plt.suptitle('Participation rates for SAT in US states from 2017 to 2019', fontsize=16)
plt.subplots_adjust(top=0.82)
plt.subplots_adjust(wspace = 0.5)

# %% [markdown]
# The box plots for SAT participation rates are similar across the years. They range greatly, with the 25th and 75th percentile at about 0.1 and 0.8 respectively. The median participation rate is about 0.5.

# %% [markdown]
# ### Boxplots for ACT Composite scores from 2017 to 2019

# %%
ax1 = plt.subplot(1, 3, 1)
ax1.boxplot(act_sat['composite_2017'], patch_artist=True, boxprops=dict(facecolor='lightgrey'))
ax1.set_title("2017")
plt.ylim([0, 36])

ax2 = plt.subplot(1, 3, 2, sharex = ax1)
ax2.boxplot(act_sat['composite_2018'], patch_artist=True, boxprops=dict(facecolor='lightgrey'))
ax2.set_title("2018")
plt.ylim([0, 36])

ax3 = plt.subplot(1, 3, 3, sharex = ax1)
ax3.boxplot(act_sat['composite_2019'], patch_artist=True, boxprops=dict(facecolor='lightgrey'))
ax3.set_title("2019")
plt.ylim([0, 36])

plt.suptitle('ACT composite scores in US states from 2017 to 2019', fontsize=16)
plt.subplots_adjust(top=0.82)
plt.subplots_adjust(wspace = 0.5)

# %% [markdown]
# The box plots for ACT composite scores are similar across the years. The median score is about 21.

# %% [markdown]
# ### Boxplots for SAT Total scores from 2017 to 2019

# %%
ax1 = plt.subplot(1, 3, 1)
ax1.boxplot(act_sat['total_2017'], patch_artist=True, boxprops=dict(facecolor='lightgrey'))
ax1.set_title("2017")
plt.ylim([400, 1600])


ax2 = plt.subplot(1, 3, 2, sharex = ax1)
ax2.boxplot(act_sat['total_2018'], patch_artist=True, boxprops=dict(facecolor='lightgrey'))
ax2.set_title("2018")
plt.ylim([400, 1600])

ax3 = plt.subplot(1, 3, 3, sharex = ax1)
ax3.boxplot(act_sat['total_2019'], patch_artist=True, boxprops=dict(facecolor='lightgrey'))
ax3.set_title("2019")
plt.ylim([400, 1600])

plt.suptitle('ACT composite scores in US states from 2017 to 2019', fontsize=16)
plt.subplots_adjust(top=0.82)
plt.subplots_adjust(wspace = 0.5)

# %% [markdown]
# The box plots for SAT total scores are similar across the years. The median score is about 1100.

# %% [markdown]
# ### Scatter plot for Participation rates for ACT and SAT  in US states from 2017 to 2019

# %%
plt.figure(figsize = (16, 5))
ax1 = plt.subplot(1, 3, 1)
ax1.scatter(act_sat['participation_2017_act'],act_sat['participation_2017_sat'])
ax1.set_title("2017")
plt.xlabel("Participation rates for ACT", fontsize=12);
plt.ylabel("Participation rates for SAT", fontsize=14)

ax2 = plt.subplot(1, 3, 2, sharex = ax1)
ax2.scatter(act_sat['participation_2018_act'],act_sat['participation_2018_sat'])
ax2.set_title("2018")
plt.xlabel("Participation rates for ACT", fontsize=12);

ax3 = plt.subplot(1, 3, 3, sharex = ax1)
ax3.scatter(act_sat['participation_2019_act'],act_sat['participation_2019_sat'])
ax3.set_title("2019")
plt.xlabel("Participation rates for ACT", fontsize=12);

plt.xlim([0, 1.1])
plt.xticks(s, s)
plt.suptitle('Participation rates for ACT and SAT in US states from 2017 to 2019', fontsize=16)

plt.subplots_adjust(top=0.82)
plt.subplots_adjust(wspace = 0.2)

# %% [markdown]
# There is a clear negative correlation between participation rates for SAT and participation rates for ACT within each year.

# %% [markdown]
# ### Scatter plot for ACT Composite and SAT Total scores in US states from 2017 to 2019

# %%
plt.figure(figsize = (16, 5))
ax1 = plt.subplot(1, 3, 1)
ax1.scatter(act_sat['composite_2017'],act_sat['total_2017'])
ax1.set_title("2017")
plt.xlabel("ACT Composite Scores", fontsize=12);
plt.ylabel("SAT Total Scores", fontsize=14)
plt.ylim([800, 1500])

ax2 = plt.subplot(1, 3, 2, sharex = ax1)
ax2.scatter(act_sat['composite_2018'],act_sat['total_2018'])
ax2.set_title("2018")
plt.xlabel("ACT Composite Scores", fontsize=12);
plt.ylim([800, 1500])

ax3 = plt.subplot(1, 3, 3, sharex = ax1)
ax3.scatter(act_sat['composite_2019'],act_sat['total_2019'])
ax3.set_title("2019")
plt.xlabel("ACT Composite Scores", fontsize=12);
plt.ylim([800, 1500])

plt.suptitle('ACT Composite and SAT Total scores in US states from 2017 to 2019', fontsize=16)

plt.xlim([15, 30])
plt.subplots_adjust(top=0.82)
plt.subplots_adjust(wspace = 0.2)

# %% [markdown]
# Judging from the scatter plots, there is a possible negative correlation between ACT composite scores and SAT total scores within each year. However, the relationship is not clear

# %% [markdown]
# ### ACT and SAT participation rates in years 2017 to 2019

# %%
year = [2017, 2018, 2019]
p_act_2017 = (act_sat.loc[:,'participation_2017_act']).mean()
p_act_2018 = (act_sat.loc[:,'participation_2018_act']).mean()
p_act_2019 = (act_sat.loc[:,'participation_2019_act']).mean()

p_sat_2017 = (act_sat.loc[:,'participation_2017_sat']).mean()
p_sat_2018 = (act_sat.loc[:,'participation_2018_sat']).mean()
p_sat_2019 = (act_sat.loc[:,'participation_2019_sat']).mean()

# %%
plt.plot(year, [p_act_2017, p_act_2018, p_act_2019], label = 'ACT', marker = 'o')
plt.plot(year, [p_sat_2017, p_sat_2018, p_sat_2019], label = 'SAT', marker = 'o')

plt.ylim([0, 1])
plt.xticks([2017, 2018, 2019], [2017, 2018, 2019])
plt.xlabel("Years", fontsize=12)
plt.ylabel("Participants", fontsize=12)
plt.suptitle('ACT and SAT participation rates in years 2017 to 2019', fontsize=14)
plt.legend();

# %% [markdown]
# Generally, ACT and SAT participation rates have been relatively stable from 2017 to 2019.If scrutinsed, mean ACT participation rates across the US States have dropped slightly while mean SAT participation rates have increased slightly from 2017 to 2019.

# %%
admission = sat_act_by_college['test_optional'].value_counts(normalize=True)
plt.bar(['Test Optional', 'Test Blind', 'Test Required'], [admission['Yes'], admission['TB'], admission['No']])

plt.ylim([0, 1])
plt.yticks(s, s)
plt.ylabel("Proportion of Colleges", fontsize=12)
plt.suptitle('Test requirements for US Colleges for at least 2021', fontsize=14);

# %%
sat_act_by_college['test_optional'].value_counts(normalize=True)
# Out:
# Yes    0.838942
# No     0.100962
# TB     0.060096
# Name: test_optional, dtype: float64

# %% [markdown]
# Mean ACT participation rates across the US States have dropped slightly from 2017 to 2019. However, mean SAT participation rates have increased slightly.

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# **Problem Statement:** <br/> You are part of the academic staff of a **NEW** public high school in **New York** and have been tasked to assess if standardized tests should be adopted in your school.

# %% [markdown]
# **Analysis:**
#
# 1) Explore the distributions of test results and participation rates over the years.<br/>
# 2) Explore how test scores and participation rates affect each other.<br/>
# 3) Are high schools still incorporating standardised tests in the curriculum? <br/>
# 4) Is there a point in taking the standardized tests? (ie. Are schools still using it as part of college entrance?) And can I afford not to take it?<br/>
# 5) Is it in my favour to take the standardized test?

# %% [markdown]
# 1) Explore the distributions of test results and participation rates over the years:<br/>
# - Distributions of participation rates for both tests are similar across the years. They cover the entire range of possible values, with clusters at the 0% and 100% participation rates.
#
# - Participation rates for a specific test and state, is generally consistent across the years.
#
# - For both tests, Test scores across the years are not normally distributed. They generally have two modes on either side of the average results.

# %% [markdown]
# 2) Explore how test scores and participation rates affect each other.<br/>
# - There is a general trend that states with high participation rates in one test have low participation rates in the other test. This is **expected** as students of a certain state will likely take either ACT or SAT, and they are not likely to take both tests

# %% [markdown]
# 3) Are high schools still incorporating standardised tests in the curriculum?<br/>
# - From 2017 to 2019 participation rates of ACT and SAT has been largely stable. At least for this period, high schools are still incorporating standardised tests in their curriculum.

# %% [markdown]
# 4) Is there a point in taking the standardized tests? (ie. Are schools still using it as part of college entrance?) And can I afford not to take it?<br/>
# - At least for 2021, almost 90% of colleges will allow applications without standardised test scores unconditionally. However, most of these colleges are not test blind, and will still consider standardised test scores if submitted.
#
# - As such, students will still have many university options even if they have not taken standardised tests.

# %% [markdown]
# 5) Will my students be at an advantage if they take standardized test?<br/>
# - In general, New York performs well in the ACT. From 2017 to 2019, New York performed better than at least 90% of the US states in ACT.

# %% [markdown]
# **Conclusions and Recommendations**
#
# While online opinion and preliminary moves from colleges support the notion that standardised testing may be less consequential next time, it is clear that colleges still currently factor in standardised test results. Since the test scores are relevant and New York generally performs well in ACT, I recommend to incorporate ACT preparations in the school curriculum.
